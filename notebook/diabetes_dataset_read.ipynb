# %%
import sys
from sklearn import preprocessing
from tensorflow import keras
from sklearn.model_selection import train_test_split
sys.path.append('../')
from app.preprocessing.diabetes import Diabetes
import numpy as np

# %%
import tensorflow as tf

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# Read dataset

# %%
diab = Diabetes()
diab.read()
# Out:
# c:\Users\Ryadh\Desktop\paris\projet_clean\DE_project_M2\notebook\..\app\preprocessing\diabetes.py:87: ParserWarning: Both a converter and dtype were specified for column chol_hdl_ratio - only the converter will be used.
#   pd.read_csv(
# c:\Users\Ryadh\Desktop\paris\projet_clean\DE_project_M2\notebook\..\app\preprocessing\diabetes.py:87: ParserWarning: Both a converter and dtype were specified for column bmi - only the converter will be used.
#   pd.read_csv(
# c:\Users\Ryadh\Desktop\paris\projet_clean\DE_project_M2\notebook\..\app\preprocessing\diabetes.py:87: ParserWarning: Both a converter and dtype were specified for column waist_hip_ratio - only the converter will be used.
#   pd.read_csv(

# %% [markdown]
# Preprocess dataset

# %%
diab.preprocess(rm_duplicates = True, normalize= False)
diab.df
# Out:
#      cholesterol_level  glucose_level  hdl_cholesterol  cholesterol_hdl_ratio  \
# 0                  193             77               49                    3.9
# 1                  146             79               41                    3.6
# 2                  217             75               54                    4.0
# 3                  226             97               70                    3.2
# 4                  164             91               67                    2.4
# ..                 ...            ...              ...                    ...
# 385                227            105               44                    5.2
# 386                226            279               52                    4.3
# 387                301             90              118                    2.6
# 388                232            184              114                    2.0
# 389                165             94               69                    2.4
#
#      age  gender  height  weight  body_mass_idx  systolic_blood_pressure  \
# 0     19       0      61     119      22.500000                      118
# 1     19       0      60     135      26.400000                      108
# 2     20       0      67     187      29.299999                      110
# 3     20       0      64     114      19.600000                      122
# 4     20       0      70     141      20.200001                      122
# ..   ...     ...     ...     ...            ...                      ...
# 385   83       0      59     125      25.200001                      150
# 386   84       0      60     192      37.500000                      144
# 387   89       0      61     115      21.700001                      218
# 388   91       0      61     127      24.000000                      170
# 389   92       0      62     217      39.700001                      160
#
#      diastolic_blood_pressure  waist_size  hip_size  waist_hip_size_ratio  \
# 0                          70          32        38                  0.84
# 1                          58          33        40                  0.83
# 2                          72          40        45                  0.89
# 3                          64          31        39                  0.79
# 4                          86          32        39                  0.82
# ..                        ...         ...       ...                   ...
# 385                        90          35        40                  0.88
# 386                        88          41        48                  0.85
# 387                        90          31        41                  0.76
# 388                        82          35        38                  0.92
# 389                        82          51        51                  1.00
#
#      diabetes
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ..        ...
# 385         0
# 386         1
# 387         0
# 388         1
# 389         0
#
# [390 rows x 15 columns]
